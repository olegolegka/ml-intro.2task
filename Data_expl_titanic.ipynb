# %%
import pandas as pd

# %%
titanic = pd.read_csv("train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie  male    NaN      2      0
# 1            1         0       3       Bryan, Drew  male    NaN      0      0
# 2            2         0       3    Owens, Kenneth  male   0.33      1      2
# 3            3         0       3     Kramer, James  male  19.00      0      0
# 4            4         1       3     Bond, Michael  male  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S
# 3   A. 10866  13.04     NaN        S
# 4     427635   7.76     NaN        S

# %%
titanic["Age"].mean()
# Out:
# 38.35547214294577

# %%
titanic[["Age", "Fare"]].median()
# Out:
# Age     39.00
# Fare    24.46
# dtype: float64

# %%
import seaborn as sns
sns.histplot(data=titanic["Age"],bins=10)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  40.044890
# male    37.030884

# %%
titanic.groupby("Sex").mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female  49983.398738  0.711525  1.918767  40.044890  0.427562  0.548740
# male    50012.092579  0.205795  2.254054  37.030884  0.374327  0.380903
#
#              Fare
# Sex
# female  55.225372
# male    35.094919

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    40.044890
# male      37.030884
# Name: Age, dtype: float64

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         105.458653
#         2          27.974629
#         3          23.945114
# male    1          78.177835
#         2          23.225431
#         3          19.156032
# Name: Fare, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    41006
# 1    30315
# 2    28679
# Name: Pclass, dtype: int64

# %%
titanic["Survived"].count()
# Out:
# 100000

# %%
titanic["Survived"].sum()
# Out:
# 42774

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
# определяем цвета 
# красный - пропущенные данные
colours = ['#eeeeee', '#ff0000']
sns.heatmap(titanic.eq(0), cmap=sns.color_palette(colours)) # data.iloc[:,:8].eq(0)
# Out:
# <AxesSubplot:>

# %%
titanic.describe()
# Out:
#          PassengerId       Survived         Pclass           Age  \
# count  100000.000000  100000.000000  100000.000000  96708.000000
# mean    49999.500000       0.427740       2.106910     38.355472
# std     28867.657797       0.494753       0.837727     18.313556
# min         0.000000       0.000000       1.000000      0.080000
# 25%     24999.750000       0.000000       1.000000     25.000000
# 50%     49999.500000       0.000000       2.000000     39.000000
# 75%     74999.250000       1.000000       3.000000     53.000000
# max     99999.000000       1.000000       3.000000     87.000000
#
#                SibSp          Parch         Fare
# count  100000.000000  100000.000000  99866.00000
# mean        0.397690       0.454560     43.92933
# std         0.862566       0.950076     69.58882
# min         0.000000       0.000000      0.68000
# 25%         0.000000       0.000000     10.04000
# 50%         0.000000       0.000000     24.46000
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB

# %%
titanic[titanic.eq(0)].count() # рассчитаем количество нулевых значений по столбцам
# Out:
# PassengerId        1
# Survived       57226
# Pclass             0
# Name               0
# Sex                0
# Age                0
# SibSp          73308
# Parch          73540
# Ticket             0
# Fare               0
# Cabin              0
# Embarked           0
# dtype: int64

# %%
titanic.replace(0, np.NaN)
# count the number of NaN values in each column
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass               Name     Sex    Age  SibSp  \
# 0            0         1       1   Oconnor, Frankie    male    NaN      2
# 1            1         0       3        Bryan, Drew    male    NaN      0
# 2            2         0       3     Owens, Kenneth    male   0.33      1
# 3            3         0       3      Kramer, James    male  19.00      0
# 4            4         1       3      Bond, Michael    male  25.00      0
# 5            5         0       2  Sassano, Jonathan    male  35.00      0
# 6            6         0       3       Conway, Jose    male   7.00      0
# 7            7         1       3      Werner, Linda  female   6.00      1
# 8            8         0       1   Wardlaw, Michael    male  27.00      2
# 9            9         0       2       Greigo, Rudy    male  66.00      0
#
#    Parch     Ticket   Fare   Cabin Embarked
# 0      0     209245  27.14  C12239        S
# 1      0      27323  13.35     NaN        S
# ...

# %%
nonall_rows=titanic.dropna(axis=0) # удаляем все строки с NaN значениями, при axis=1 - то же со столбцами
nonall_rows
# Out:
#        PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 8                8         0       1  Wardlaw, Michael    male  27.0      2
# 9                9         0       2      Greigo, Rudy    male  66.0      0
# 11              11         0       1  Telschow, Robert    male  60.0      0
# 12              12         0       3      Stewart, Pat    male  36.0      0
# 14              14         1       1     Seaton, Karen  female  44.0      0
# ...            ...       ...     ...               ...     ...   ...    ...
# 99967        99967         0       1   Harrier, Stacey    male  49.0      2
# 99989        99989         1       1       Harris, Amy  female  64.0      0
# 99991        99991         0       1       Hogan, Todd    male  53.0      0
# 99992        99992         1       2     Cordero, Rita  female  58.0      0
# 99995        99995         1       2       Bell, Adele  female  62.0      0
#
#        Parch    Ticket    Fare   Cabin Embarked
# ...

# %%
nonall_cols=titanic.dropna(axis=1,thresh=600) # удаляем столбцы, в которых  значений не NaN меньше 600
nonall_cols
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# ...

# %%
data_mean=titanic["Age"].fillna(titanic["Age"].mean())

# %%
data_mean.head(900)
# Out:
# 0      38.355472
# 1      38.355472
# 2       0.330000
# 3      19.000000
# 4      25.000000
#          ...
# 895    62.000000
# 896    39.000000
# 897    22.000000
# 898    64.000000
# 899    54.000000
# Name: Age, Length: 900, dtype: float64

# %%
data_mean.isna().sum() # можно убедиться, что значений NaN не осталось
# Out:
# 0

# %%
data_prev=titanic.fillna(value=None, method="ffill")
data_prev.head(10)
# Out:
#    PassengerId  Survived  Pclass               Name     Sex    Age  SibSp  \
# 0            0         1       1   Oconnor, Frankie    male    NaN      2
# 1            1         0       3        Bryan, Drew    male    NaN      0
# 2            2         0       3     Owens, Kenneth    male   0.33      1
# 3            3         0       3      Kramer, James    male  19.00      0
# 4            4         1       3      Bond, Michael    male  25.00      0
# 5            5         0       2  Sassano, Jonathan    male  35.00      0
# 6            6         0       3       Conway, Jose    male   7.00      0
# 7            7         1       3      Werner, Linda  female   6.00      1
# 8            8         0       1   Wardlaw, Michael    male  27.00      2
# 9            9         0       2       Greigo, Rudy    male  66.00      0
#
#    Parch     Ticket   Fare   Cabin Embarked
# 0      0     209245  27.14  C12239        S
# 1      0      27323  13.35  C12239        S
# ...

# %%
titanic["Sex"]=titanic["Sex"].map({"male": 1, "female": 0})#Заменим пол на 1 если male и 0 если female

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass              Name  Sex    Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie    1    NaN      2      0
# 1            1         0       3       Bryan, Drew    1    NaN      0      0
# 2            2         0       3    Owens, Kenneth    1   0.33      1      2
# 3            3         0       3     Kramer, James    1  19.00      0      0
# 4            4         1       3     Bond, Michael    1  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S
# 3   A. 10866  13.04     NaN        S
# 4     427635   7.76     NaN        S

# %%
titanic.info() # можно заметить, что все параметры теперь - числа, кроме Churn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  int64
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 9.2+ MB

# %%
titanic.drop(["Name", "Ticket", "Cabin"], axis=1, inplace=True)

# %%
y = titanic["Survived"].astype("int") # Формируем вектор меток У

# %%
X = titanic.drop(["Embarked", "Survived", "PassengerId"], axis=1)
X.head()
# Out:
#    Pclass  Sex    Age  SibSp  Parch   Fare
# 0       1    1    NaN      2      0  27.14
# 1       3    1    NaN      0      0  13.35
# 2       3    1   0.33      1      2  71.29
# 3       3    1  19.00      0      0  13.04
# 4       3    1  25.00      0      0   7.76

# %%
X = X.fillna(X["Age"].mean()) #Заполним nan значения средним

# %%
X.shape, y.shape # проверим размерность
# Out:
# ((100000, 6), (100000,))
